# %% [markdown]
# ##Python Module End Assignment (Comprehensive Assessment)

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data set
df = pd.read_csv('myexcel.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
print('Shape :', df.shape)

#get basic informations
df.info()
# Out:
# Shape : (458, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# # Preprocessing:
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis.

# %%
df['Height'] = np.random.randint(150,180,size=len(df))

print("Data set after updated height : \n")
df
# Out:
# Data set after updated height :
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     167     235
# 2     John Holland  Boston Celtics      30       SG   27     174     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     171     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     175     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     169     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     167     231
#
#                College     Salary
# ...

# %% [markdown]
# # Analysis Tasks:

# %% [markdown]
# # 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
#Determine the distribution of each employees across each team
team_counts = df['Team'].value_counts()
print("The distribution of each employees across each team : \n", team_counts)
# Out:
# The distribution of each employees across each team :
#  Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# ...

# %%
#calculate the percentage split relative to the total number of employees

team_percentage = (team_counts/team_counts.sum())*100
#datframe for better visualization
distribution_df = pd.DataFrame({
    'Team' : team_counts.index,
    'number of employees' : team_counts.values,
    'percentage':team_percentage.values
   }   
)
print("The percentage split relative to the total number of employees : \n" , distribution_df)
# Out:
# The percentage split relative to the total number of employees :
#                        Team  number of employees  percentage
# 0     New Orleans Pelicans                   19    4.148472
# 1        Memphis Grizzlies                   18    3.930131
# 2                Utah Jazz                   16    3.493450
# 3          New York Knicks                   16    3.493450
# 4          Milwaukee Bucks                   16    3.493450
# 5            Brooklyn Nets                   15    3.275109
# 6   Portland Trail Blazers                   15    3.275109
# 7    Oklahoma City Thunder                   15    3.275109
# 8           Denver Nuggets                   15    3.275109
# 9       Washington Wizards                   15    3.275109
# 10              Miami Heat                   15    3.275109
# 11       Charlotte Hornets                   15    3.275109
# 12           Atlanta Hawks                   15    3.275109
# 13       San Antonio Spurs                   15    3.275109
# ...

# %% [markdown]
# **Graphical Representation**

# %%
plt.figure(figsize=(20,8))
sns.barplot(x="Team",y="number of employees",data=distribution_df,hue="Team",palette = 'plasma')
plt.title("Number of employees by team")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **data story**
#
# The barplot analysis shows that, the team 'New Orleans Pelicans' has highest number of employees that is 19.
# and closely followed by 'Memphis Grizzlies' as 18.
# Majority teams have 15 employees

# %% [markdown]
# # 2. Segregate employees based on their positions within the company.

# %%
position_counts = df['Position'].value_counts()
#number of employees each position
print(position_counts)

# Group employees by Position
groups = df.groupby('Position')

# Print each group
for position, group in groups:
   print(f"\nPosition: {position}")
   print(group[['Name','Position']])
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64
#
# Position: C
#                 Name Position
# 7       Kelly Olynyk        C
# 10   Jared Sullinger        C
# 14      Tyler Zeller        C
# 23       Brook Lopez        C
# 27        Henry Sims        C
# ..               ...      ...
# 439    Mason Plumlee        C
# 447      Rudy Gobert        C
# 455     Tibor Pleiss        C
# 456      Jeff Withey        C
# 457         Priyanka        C
#
# [79 rows x 2 columns]
#
# Position: PF
#                  Name Position
# 4       Jonas Jerebko       PF
# 5        Amir Johnson       PF
# 6       Jordan Mickey       PF
# 24   Chris McCullough       PF
# 25        Willie Reed       PF
# ..                ...      ...
# 435    Meyers Leonard       PF
# 441       Noah Vonleh       PF
# 442     Trevor Booker       PF
# 446    Derrick Favors       PF
# 452        Trey Lyles       PF
#
# [100 rows x 2 columns]
#
# Position: PG
# ...

# %% [markdown]
# **Graphical Representation**

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=position_counts.index,y=position_counts.values)
plt.ylabel("Number of employees")
plt.title("Employee count by position")
# Out:
# Text(0.5, 1.0, 'Employee count by position')

# %% [markdown]
# **data story**
#
# According to barplot analysis, more employees are residing in the SG position ie,102 and closely followed by PF position ie 100 employees

# %% [markdown]
# # 3. Identify the predominant age group among employees.

# %%
df['Age'] # Age column
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
df['Age'].unique() # get unique age
# Out:
# array([25, 27, 22, 29, 21, 24, 20, 26, 28, 32, 23, 30, 33, 34, 37, 36, 31,
#        38, 39, 19, 35, 40], dtype=int64)

# %%
df['Age'].nunique()  #number of unique values in dataframe
# Out:
# 22

# %%
age_counts = df['Age'].value_counts() # number of employees in each age
print(age_counts)
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %% [markdown]
# **Graphical Representation**

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Age',data=df,hue="Age")
plt.ylabel("Number of employees")
plt.title("Employees count by age")
# Out:
# Text(0.5, 1.0, 'Employees count by age')

# %% [markdown]
# **Data Story:**
#
# Most of the employees age fall within the age of 24 and 25, with 47 and 46 respectively. The count of employees slightly decreases as age increases

# %%
df['Age Group'] = df['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31<= age <=35 else '36-40')))

df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary Age Group
# 0                Texas  7730337.0     20-25
# ...

# %%
df['Age Group'].value_counts()
# Out:
# Age Group
# 20-25    198
# 26-30    167
# 31-35     68
# 36-40     25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Age Group',data= df, hue = 'Age Group')
plt.ylabel("Number of employees")
plt.title("Employees count by Age Group")
# Out:
# Text(0.5, 1.0, 'Employees count by Age Group')

# %% [markdown]
# **Data Story:**
#
# In this analysis, majority of employess about 198 are under the range of 20-25 and fewer employees are within the range of 36-40

# %% [markdown]
# # 4. Discover which team and position have the highest salary expenditure.

# %%
#missing values in each column
print(df.isnull().sum())
# Out:
# Name          0
# Team          0
# Number        0
# Position      0
# Age           0
# Height        0
# Weight        0
# College      84
# Salary       11
# Age Group     0
# dtype: int64

# %%
#fill missing values in salary with mean
x= df['Salary'].mean()
df['Salary'].fillna(x,inplace=True)
df
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8132\3975479276.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(x,inplace=True)
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# ...

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 9.472760e+05    32
# 8.450590e+05    18
# 5.250930e+05    13
# 4.833970e+06    11
# 9.813480e+05     6
#                 ..
# 2.100000e+06     1
# 1.252440e+06     1
# 2.891760e+06     1
# 3.272091e+06     1
# 9.000000e+05     1
# Name: count, Length: 310, dtype: int64

# %%
df_filterd = df[['Name','Team','Position','Salary']]
df_filterd
# Out:
#               Name            Team Position        Salary
# 0    Avery Bradley  Boston Celtics       PG  7.730337e+06
# 1      Jae Crowder  Boston Celtics       SF  6.796117e+06
# 2     John Holland  Boston Celtics       SG  4.833970e+06
# 3      R.J. Hunter  Boston Celtics       SG  1.148640e+06
# 4    Jonas Jerebko  Boston Celtics       PF  5.000000e+06
# ..             ...             ...      ...           ...
# 453   Shelvin Mack       Utah Jazz       PG  2.433333e+06
# 454      Raul Neto       Utah Jazz       PG  9.000000e+05
# 455   Tibor Pleiss       Utah Jazz        C  2.900000e+06
# 456    Jeff Withey       Utah Jazz        C  9.472760e+05
# 457       Priyanka       Utah Jazz        C  9.472760e+05
#
# [458 rows x 4 columns]

# %%
#find maximum salary
total_salary = df.groupby(['Team','Position'])['Salary'].sum()
print(total_salary)
max_salary_data = total_salary.idxmax() # output ('Los Angeles Lakers', 'SF')
max_salary = total_salary.max()

print(f"Team and position have the highest salary is \n Team : {max_salary_data[0]} \n Position : {max_salary_data[1]} \n Highest salary : {max_salary}")
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64
# Team and position have the highest salary is
#  Team : Los Angeles Lakers
#  Position : SF
#  Highest salary : 31866445.0

# %% [markdown]
# **Graphical Representation**

# %%
total_salary = df.groupby(['Team','Position'])['Salary'].sum().reset_index()
#reset_index() is used to turn the resulting Series back into a DataFrame for easier plotting.
print(total_salary)
plt.figure(figsize=(20,8))
# Scatter plot
sns.scatterplot(data=total_salary, x='Team', y='Salary', hue='Position')

plt.xlabel('Team')
plt.ylabel('Total Salary')
plt.title('Scatter plot position Vs Team with salary')
plt.xticks(rotation = 90)
plt.show()
# Out:
#                    Team Position      Salary
# 0         Atlanta Hawks        C  22756250.0
# 1         Atlanta Hawks       PF  23952268.0
# 2         Atlanta Hawks       PG   9763400.0
# 3         Atlanta Hawks       SF   6000000.0
# 4         Atlanta Hawks       SG  10431032.0
# ..                  ...      ...         ...
# 144  Washington Wizards        C  24490429.0
# 145  Washington Wizards       PF  11300000.0
# 146  Washington Wizards       PG  18022415.0
# 147  Washington Wizards       SF  11158800.0
# 148  Washington Wizards       SG  11356992.0
#
# [149 rows x 3 columns]

# %% [markdown]
# **Data Story :**
#
#  It reveals that the team Los Angeles Lakers SF position is the high salaried team

# %% [markdown]
# # 5. Investigate if there's any correlation between age and salary, and represent it visually.

# %% [markdown]
# **correlation**:
# measures the relationship between two variables. Values range from -1 to +1
# Values close to +1 indicates strong positive correlation, -1 indicates a strong negative correlation and 0 indicates suggests no linear correlation.
# Positive correlation variable move in same directions. As one increases, the other also increases.
# Negative correlation variable move in opposite directions. An increase in one variable is associated with a decrease in the other.
#
# **Heat Maps**
# A heatmap is a graphical representation of data where individual values are represented by color gradients. It is a useful tool for visualizing the magnitude of values in a matrix or table format. Heatmaps are commonly used to display correlation matrices, data density, and other types of data where relationships and patterns can be better understood through color variations.

# %%
df1 = df[['Age','Salary']]
df1
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
corr = df1.corr()
corr
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %% [markdown]
# **Graphical representation**

# %%
sns.heatmap(corr,cmap="YlGnBu",annot=True)
plt.title("Correlation matrix between age salary of employees")
plt.show()

# %% [markdown]
# **Data Story**
# This correlation shows relationship between age and salary
# Age vs Age (1.00000) :  This represents correlation of variable with itself, which is always 1 . It is positive correlation
#
# Age vs Salary (0.21117) : This represents positive but relatively weak relationship between age and salary.This means that as age increases, there's a tendency for salaries to increase slightly, but the correlation isn't very strong.
#
# Salary vs Age (0.21117): weak positive relationship between the two variables.
