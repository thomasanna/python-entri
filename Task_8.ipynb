# %% [markdown]
# #Matplotlib

# %% [markdown]
# ##1. 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title. The code snippet gives the output shown in the following screenshot:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0,50])
y = np.array([0,160])
plt.plot(x,y)
plt.title('Draw a line')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# plt.xlim(0, max(x))
# plt.ylim(0, max(y))
plt.show()

# %% [markdown]
# ##2 Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title. The code snippet gives the output shown in the following screenshot:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1,2,3])
y = np.array([2,4,1])
plt.plot(x,y)
plt.xlim(1, max(x))
plt.ylim(1, max(y))
plt.title("Sample graph!")
plt.xlabel("X-axis")
plt.ylabel("Y-label")
plt.show()

# %% [markdown]
# ##3. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# ```
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017
# The code snippet gives the output shown in the following screenshot:
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Read the data from the CSV file
data = pd.read_csv('fdata.csv')
print(data)

# Plot 'Open'
plt.plot(data['Date'], data['Open'], label='Open')
#plot 'High'
plt.plot(data['Date'],data['High'],  label='High')
#plot 'Low'
plt.plot(data['Date'],data['Low'],label = 'Low')
#plot 'Close'
plt.plot(data['Date'],data['Close'],label='Close')

plt.legend()  # It automatically creates a legend using the labels specified in the plt.plot() function calls

plt.show()
# Out:
#          Date        Open        High         Low       Close
# 0  10-03-2016  774.250000  776.065002  769.500000  772.559998
# 1  10-04-2016  776.030029  778.710022  772.890015  776.429993
# 2  10-05-2016  779.309998  782.070007  775.650024  776.469971
# 3  10-06-2016  779.000000  780.479980  775.539978  776.859985
# 4  10-07-2016  779.659973  779.659973  770.750000  775.080017

# %% [markdown]
# ##4.  Write a Python program to plot two or more lines with legends, different widths and colors. The code snippet gives the output shown in the following screenshot:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([10,20,30])
y = np.array([20,40,10])
a = np.array([10,20,30])
b = np.array([40,10,30])
plt.plot(x,y,label ='line1-width-3',color='blue',linewidth =3)
plt.plot(a,b,label = 'line2-width-5',color ='red',linewidth =5)
# Adjusting x-axis ticks
plt.xticks(np.arange(10, 35, 5)) # np.arange(10, 35, 5), the parameters represent the start, stop, and step values 
plt.xlim(10, max(x))
plt.ylim(10, max(y))
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Two or more lines with diffrent widths and colors with suitable legends')
plt.legend()
plt.show()

# %% [markdown]
# ##5 Write a Python program to plot quantities which have an x and y position. The code snippet gives the output shown in the following screenshot:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([2,3,5,6,8])
y = np.array([0,5,10,15.5,19])
a = np.array([3,4,6,7,9])
b = np.array([2,6,11,19,22])
plt.figure(figsize=(10, 7),dpi = 100)
plt.scatter(x,y,marker ='*',color='blue')
plt.scatter(a,b,marker='o',color='red')
plt.xticks(np.arange(0, 12, 2)) 
plt.yticks(np.arange(0, 35, 5))
plt.show()

# %% [markdown]
# ##6.  Write a Python programming to display a bar chart of the popularity of programming Languages.
# ```
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# The code snippet gives the output shown in the following screenshot:
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import numpy as np
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.figure(figsize=(10, 7),dpi = 100)
plt.bar(languages,popularity,color="blue")

plt.yticks(np.arange(0, 30, 5))
plt.grid(axis='x', linestyle='--',fillstyle = 'full')
plt.grid(axis='y', linestyle='-', alpha=0.7 ,color='r',fillstyle = 'full') #alpha=0.7: Sets the transparency of the grid lines.
#plt.gca().xaxis.set_major_locator(MultipleLocator(0.2))  # Set grid distance to 0.2 on the x-axis
#plt.gca().xaxis.set_major_locator(plt.MultipleLocator(2))  # Set grid distance to 5 on the y-axis
plt.xlabel('Langages')
plt.ylabel('Popularity')


plt.title('Popularity of programming languages \n Worldwide, Oct 2017 compared to a year ago')
plt.show()

# %% [markdown]
# ##7.  Write a Python programming to display a horizontal bar chart of the popularity of programming Languages.
# ```
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# The code snippet gives the output shown in the following screenshot:
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.figure(figsize=(10, 7),dpi = 100)
plt.barh(languages,popularity,color="green")
plt.grid(axis='x', linestyle='--')
plt.grid(axis='y', linestyle='-', alpha=0.7 ,color='r') #alpha=0.7: Sets the transparency of the grid lines.
plt.xlabel('Popularity')
plt.ylabel('Langages')
plt.title('Popularity of programming languages \n Worldwide, Oct 2017 compared to a year ago')
plt.show()

# %% [markdown]
# # Use the following CSV file for this exercise. Read this file using Pandas

# %%
# !wget https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %%
import pandas as pd

# Read the CSV file using Pandas
df = pd.read_csv('company_sales_data.csv')
print(df)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# ##Exercise 1: Read Total profit of all months and show it using a line plot
#
# Total profit data provided for each month. Generated line plot must include the following properties: –
# ```
# X label name = Month Number
# Y label name = Total profit
# ```
#
# The line plot graph should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
months = df['month_number']
total_profit = df['total_profit']
plt.figure(figsize=(10,6))
plt.plot(months,total_profit)
font1 = {'family':'serif','size':15}
font2 = {'family':'serif','size':20}
plt.xlabel('Month Number',fontdict = font1)
plt.ylabel('Total Profit',fontdict = font1)
plt.title('Company profit per month',fontdict = font2)
# Set specific x-axis ticks
plt.xticks(ticks=months)
plt.show()

# %% [markdown]
# ##Exercise 2: Get total profit of all months and show line plot with the following Style properties
#
# ```
# Generated line plot must include following Style properties: –
#
# Line Style dotted and Line-color should be red
# Show legend at the lower right location.
# X label name = Month Number
# Y label name = Sold units number
# Add a circle marker.
# Line marker color as read
# Line width should be 3
#
# ```
# The line plot graph should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

months = df['month_number']
total_profit = df['total_profit']
plt.figure(figsize=(10,6))
plt.plot(months,total_profit,marker='o',ms=8 ,linestyle="--",color='r',markerfacecolor="black",linewidth =3,label = 'Profit data of last year')
font1 = {'family':'serif','size':15}
font2 = {'family':'serif','size':20}
plt.xlabel('Month Number',fontdict = font1)
plt.ylabel('Sold units number',fontdict = font1)
plt.title('Company sales data of last year',fontdict = font2)
plt.xticks(months) #the parameters represent the start, stop, and step values 
plt.yticks(np.arange(100000, 600000, 100000)) #the parameters represent the start, stop, and step values 
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ##Exercise 3: Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
#
# The graph should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,7))
plt.plot(df['month_number'],df['facecream'] , marker='o',linewidth = 3,label ='Face cream sales data',ms=10) #ms marker size
plt.plot(df['month_number'],df['facewash'], marker='o',linewidth = 3,label = 'Face wash sales data' ,ms=10)
plt.plot(df['month_number'],df['toothpaste'], marker='o',linewidth = 3,label='Toothpaste sales data' ,ms=10)
plt.plot(df['month_number'],df['bathingsoap'], marker='o',linewidth = 3, label ='Bathing soap sales data' ,ms=10)
plt.plot(df['month_number'],df['shampoo'], marker='o',linewidth = 3, label ='Shampoo sales data',ms=10)
plt.plot(df['month_number'],df['moisturizer'], marker='o',linewidth = 3, label='Moisturiser sales data',ms=10)
plt.xticks(df['month_number']) #the parameters represent the start, stop, and step values 
font1 = {'family':'serif','size':15}
font2 = {'family':'serif','size':20}
plt.xlabel('Month Number',fontdict = font1)
plt.ylabel('Sales units in number',fontdict = font1)
plt.title('Sales data',fontdict = font2)
plt.legend()
plt.show()

# %% [markdown]
# ##Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot. gridline style should “–“.
#
# The scatter plot should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(df['month_number'],df['toothpaste'],label ='Tooth paste sales data',s=60) # s - marker size
plt.xticks(np.arange(1, 13, 1)) #the parameters represent the start, stop, and step values 
font1 = {'family':'serif','size':15}
font2 = {'family':'serif','size':20}
plt.xlabel('Month Number',fontdict = font1)
plt.ylabel('Number of units sold',fontdict = font1)
plt.title('Tooth paste Sales data',fontdict = font2)
plt.grid(linestyle='--')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# ##Exercise 5: Read face cream and facewash product sales data and show it using the bar chart
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.figure(figsize=(10,7))
bar_width = 0.35 # the width of the bars

month_number = df['month_number']
# Select only facecream and facewash columns
df_filtered = df[['facecream', 'facewash']]

data = df_filtered.to_dict(orient='list') #dataframe to dictionary

x = np.arange(len(month_number))  # the label locations


# Plot each attribute as a separate group of bars
multiplier = 0

for attribute, measurement in data.items():
    offset = bar_width * multiplier  # calculate the offset for the group of bars
    if attribute == 'facecream':
        label_n = 'Face Cream sales Data'
    else:
        label_n = 'Face wash sales data'
    rects = plt.bar(x + offset, measurement, bar_width, label=label_n) 
    #plt.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
font1 = {'family':'serif','size':15}
font2 = {'family':'serif','size':20}

plt.ylabel('Sales units in number',fontdict = font1)
plt.xlabel('Month number',fontdict = font1)
plt.title('Face wash and Face Cream Sales Data',fontdict = font2)
plt.xticks(x + bar_width, month_number)
plt.legend(loc='upper left', ncols=3)
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# ##Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
# The bar chart should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

month_number = df['month_number']
bathing_soap = df['bathingsoap']

plt.figure(figsize=(10,6))
plt.bar(month_number,bathing_soap)
plt.xticks(month_number)
plt.xlabel('Month Number')
plt.ylabel('Sales unit in number')
plt.title('Bathing soap sales data')
plt.grid(linestyle='--')
# Save the plot to the hard disk
plt.savefig('bathingsoap_sales.png')
plt.show()

# %% [markdown]
# ##Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
# The histogram should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

total_profitt = df['total_profit']
print(total_profitt)
plt.figure(figsize=(10,6))
plt.hist(total_profitt, bins=5, label ='Profit data')
plt.legend(loc='upper left')
plt.xlabel('Profit range in dollar')
plt.ylabel('Actual profit in dollar')
plt.title('Profit data')
plt.show()
# Out:
# 0     211000
# 1     183300
# 2     224700
# 3     222700
# 4     209600
# 5     201400
# 6     295500
# 7     361400
# 8     234000
# 9     266700
# 10    412800
# 11    300200
# Name: total_profit, dtype: int64

# %% [markdown]
# ##Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

total_sales = {
    'FaceCream'    : df['facecream'].sum(),
    'FaceWash'     : df['facewash'].sum(),
    'ToothPaste'   : df['toothpaste'].sum(),
    'Bathing soap' : df['bathingsoap'].sum(),
    'Shampoo'      : df['shampoo'].sum(),
    'Moisturizer'  : df['moisturizer'].sum()
}

plt.figure(figsize=(10,6))
plt.pie(total_sales.values(), labels = total_sales.keys(), autopct='%1.1f%%')
plt.legend(loc = 'lower right')
plt.title('Sales Data')
plt.show()

# %% [markdown]
# ##Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
# The Subplot should look like this.
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
month_number = df['month_number']
plt.figure(figsize=(10,6))
#plot 1
plt.subplot(2,1,1)
# `plt.subplot(2,1,1)` -> the figure has 2 row, 1 columns, and this plot is the first plot.
plt.plot(month_number,df['bathingsoap'],color='black' , marker='o')
plt.title('Sales data of a bathingsoap')
plt.xticks([])
#plot2

plt.subplot(2,1,2)
plt.plot(month_number,df['facewash'],color ='r',marker='o')
# `plt.subplot(2,1,2)` ->the figure has 2 row, 1 columns, and this plot is the second plot.
plt.xticks(month_number)
plt.xlabel('Month Number')
plt.ylabel('Sales unit in number')
plt.title('Sales data of a facewash')
plt.show()

# %% [markdown]
# ##Exercise Question 10: Read all product sales data and show it using the stack plot
# The Stack plot should look like this.
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
months             = df['month_number']
facecream_sales    = df['facecream']
facewash_sales     = df['facewash']
toothpaste_sales   = df['toothpaste']
bathingsoap_sales  = df['bathingsoap']
shampoo_sales      = df['shampoo']
moisturizer_sales  = df['moisturizer']

labels = ['face Cream','Face Wash','Tooth paste','Bathing soap','Shampoo','Moisturizer']
colors=['m','c','r','k','g','y']
plt.stackplot(months,facecream_sales,facewash_sales,toothpaste_sales,bathingsoap_sales,shampoo_sales,moisturizer_sales, labels=labels,colors =colors)
plt.xlabel('Month Number')
plt.ylabel('Sales unit in number')
plt.title('All products sales data using slack plot')
plt.legend()
plt.show()
